# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghanaShanthappa/TensorRT_features/blob/main/Profiling_in_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision.models as models
from torch.profiler import profile, ProfilerActivity, record_function

# %%
model = models.resnet18()
inputs = torch.randn(5, 3, 224, 224)

# %%
with profile(activities=[ProfilerActivity.CPU], record_shapes=True) as prof:
    with record_function("model_inference"):
        model(inputs)

# %%
print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                   model_inference         2.42%      21.514ms       100.00%     889.459ms     889.459ms             1
#                      aten::conv2d         0.52%       4.642ms        76.41%     679.662ms      33.983ms            20
#                 aten::convolution         0.53%       4.686ms        75.89%     675.020ms      33.751ms            20
#                aten::_convolution         0.35%       3.142ms        75.36%     670.335ms      33.517ms            20
#          aten::mkldnn_convolution        74.31%     660.935ms        75.01%     667.192ms      33.360ms            20
# ...

# %%
print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                   model_inference         2.42%      21.514ms       100.00%     889.459ms     889.459ms             1
#                      aten::conv2d         0.52%       4.642ms        76.41%     679.662ms      33.983ms            20
#                 aten::convolution         0.53%       4.686ms        75.89%     675.020ms      33.751ms            20
#                aten::_convolution         0.35%       3.142ms        75.36%     670.335ms      33.517ms            20
#          aten::mkldnn_convolution        74.31%     660.935ms        75.01%     667.192ms      33.360ms            20
# ...
